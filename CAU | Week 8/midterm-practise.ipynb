# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread("../data/images/coins.png")

# %% [markdown]
# ## Gamma correction, aka power law
# 1. Using LUT table - speed, more efficient
# 2. Using simpler way for examples

# %%
def power_law(img, gamma):
    # Create an array of 0-255
    x = np.arange(256, dtype='float32')

    # Calculate values for all the 255 pixels at once
    table = np.clip(((x / 255) ** gamma) * 255.0, 0, 255).astype('uint8')

    # Apply power law
    return cv2.LUT(img, table)

# %%
output_image = power_law(image, 0.4)
plt.imshow(output_image)
plt.axis("off")
plt.show()
